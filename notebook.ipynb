# %%
import flor

# %%
flor.query("SELECT * FROM loops")
# Out:
#     ctx_id  parent_ctx_id loop_name  loop_entries  loop_iteration
# 0        0            NaN     epoch             1               1
# 1        1            0.0      step             1             500
# 2        2            0.0      step             1            1000
# 3        3            0.0      step             1            1500
# 4        4            NaN     epoch             1               2
# 5        5            4.0      step             2             500
# 6        6            4.0      step             2            1000
# 7        7            4.0      step             2            1500
# 8        8            NaN     epoch             1               3
# 9        9            8.0      step             3             500
# 10      10            8.0      step             3            1000
# 11      11            8.0      step             3            1500
# 12      12            NaN     epoch             1               4
# ...

# %%
flor.pivot('accuracy', 'loss')
# Out:
#          projid               tstamp  filename accuracy  epoch_entries  \
# 0   ml_tutorial  2023-08-17T14:08:13  train.py    97.94              1
# 1   ml_tutorial  2023-08-17T14:08:13  train.py    97.94              1
# 2   ml_tutorial  2023-08-17T14:08:13  train.py    97.94              1
# 3   ml_tutorial  2023-08-17T14:08:13  train.py    97.94              1
# 4   ml_tutorial  2023-08-17T14:08:13  train.py    97.94              1
# 5   ml_tutorial  2023-08-17T14:08:13  train.py    97.94              1
# 6   ml_tutorial  2023-08-17T14:08:13  train.py    97.94              1
# 7   ml_tutorial  2023-08-17T14:08:13  train.py    97.94              1
# 8   ml_tutorial  2023-08-17T14:08:13  train.py    97.94              1
# 9   ml_tutorial  2023-08-17T14:08:13  train.py    97.94              1
# 10  ml_tutorial  2023-08-17T14:08:13  train.py    97.94              1
# 11  ml_tutorial  2023-08-17T14:08:13  train.py    97.94              1
# ...
